# %% [markdown]
# take data as csv file
# you can just put df on it's own to print out the dataframe

# %%
import pandas as pd

# %%
df = pd.read_csv('Readable2.csv')

# %%
df
# Out:
#      Treatment  avg released LDH  LDH ttest  LDH total avg  % cytotoxicity  \
# 0      Control          0.960750        NaN        1.73450        0.000000
# 1      HQ*1000          0.797875   0.049691        1.47725        6.807270
# 2          SPK          0.766250   0.470272        1.65250        1.990600
# 3       HQ*100          0.785375   0.243736        1.59200        4.400000
# 4  SPK+HQ*1000          0.734500   0.482552        1.55500       -1.704369
# 5   SPK+HQ*100          0.751750   0.892088        1.41175        0.527506
#
#     MTT avg  MTT ttest  MTT % viability
# 0  0.441000        NaN       100.000000
# 1  0.455167   0.519827       103.212396
# 2  0.512000   0.140386       116.099773
# 3  0.477500   0.367692       108.276644
# 4  0.464167   0.580860       105.253212
# 5  0.459333   0.668565       104.157218

# %%
df.plot(x='Treatment', y='avg released LDH', kind='bar')
df.plot(x='Treatment', y='LDH ttest', kind='bar')
df.plot(x='Treatment', y='LDH total avg', kind='bar')
df.plot(x='Treatment', y='% cytotoxicity', kind='bar')
df.plot(x='Treatment', y='MTT avg', kind='bar')
df.plot(x='Treatment', y='MTT ttest', kind='bar')
df.plot(x='Treatment', y='MTT % viability', kind='bar')
# Out:
# <AxesSubplot:xlabel='Treatment'>

# %%
df.plot(x='Treatment', y='MTT avg', kind='bar')
df.plot(x='Treatment', y='MTT ttest', kind='bar')
df.plot(x='Treatment', y='MTT % viability', kind='bar')
# Out:
# <AxesSubplot:xlabel='Treatment'>

# %%
df.shape #gives info on rows and columns

# %%
df.info #gives ALL the info

# %%
df.set_option('display.max_columns', 86) #put a column limit

# %%
schema_df = pd.read_csv('readableSchema.csv')

# %%
schema_df #shows the Definitions of each of the columns
